# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_drug_df = pd.read_csv("data/mouse_drug_data.csv")
clinical_trial_df = pd.read_csv("data/clinicaltrial_data.csv")

# Combine the data into a single dataset
combined_pymaceuticals_data = pd.merge(clinical_trial_df, mouse_drug_df, on="Mouse ID")

# Display the data table for preview
combined_pymaceuticals_data.sort_values(by='Timepoint', ascending=True).head()
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0        b128          0                45.0                 0  Capomulin
# 1535     i635          0                45.0                 0   Propriva
# 565      g791          0                45.0                 0   Ramicane
# 1545     w746          0                45.0                 0   Propriva
# 1547     r107          0                45.0                 0   Propriva

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

# %%
# Retrieve Drug, Timepoint,Tumor Volume (mm3) column data
tumor_data = combined_pymaceuticals_data[["Drug", "Timepoint","Tumor Volume (mm3)"]]
# Grouped by Drug and Timepoint
avg_tumor_vol= tumor_data.groupby(["Drug","Timepoint"])
# Mean tumor volume (mm3)
tumor_response = avg_tumor_vol.mean()
tumor_response = tumor_response.reset_index()
tumor_response
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0           45.000000
# 1   Capomulin          5           44.266086
# 2   Capomulin         10           43.084291
# 3   Capomulin         15           42.064317
# 4   Capomulin         20           40.716325
# ..        ...        ...                 ...
# 95  Zoniferol         25           55.432935
# 96  Zoniferol         30           57.713531
# 97  Zoniferol         35           60.089372
# 98  Zoniferol         40           62.916692
# 99  Zoniferol         45           65.960888
#
# [100 rows x 3 columns]

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint

# Convert to DataFrame

# Preview DataFrame

# %%
# Standard Error of Tumor Volumes Grouped by Drug and Timepoint

std_err_tumor = avg_tumor_vol.sem()
std_err_tumor =std_err_tumor.reset_index()
std_err_tumor.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

# %%
reformat_tumor_resp = tumor_response.reset_index().pivot("Timepoint", "Drug", "Tumor Volume (mm3)")
reformat_tumor_resp.head()
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Generate the plot (with Error Bars)
#Save the Figure

# %%
reformat_std_err_tumor = std_err_tumor.reset_index().pivot("Timepoint", "Drug", "Tumor Volume (mm3)")
reformat_std_err_tumor.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.231708  0.482955  0.239862   0.188950
# 10         0.376195  0.720225  0.433678   0.263949
# 15         0.466109  0.770432  0.493261   0.370544
# 20         0.555181  0.786199  0.621889   0.533182

# %%
# Generate the Plot (with Error Bars) 
plt.errorbar(reformat_tumor_resp.index,reformat_tumor_resp["Capomulin"],yerr= reformat_std_err_tumor["Capomulin"],color="r",
             marker="o", markersize= 5,linestyle = "dashed", linewidth = 0.5, label= "Capomulin")
plt.errorbar(reformat_tumor_resp.index,reformat_tumor_resp["Infubinol"],yerr= reformat_std_err_tumor["Infubinol"],color="b",
             marker="^", markersize= 5,linestyle = "dashed", linewidth = 0.5, label = "Infubinol" )
plt.errorbar(reformat_tumor_resp.index,reformat_tumor_resp["Ketapril"],yerr= reformat_std_err_tumor["Ketapril"],color="g",
             marker="s", markersize= 5,linestyle = "dashed", linewidth = 0.5, label = "Ketapril")
plt.errorbar(reformat_tumor_resp.index,reformat_tumor_resp["Placebo"],yerr= reformat_std_err_tumor["Placebo"],color="k",
             marker="d", markersize= 5,linestyle = "dashed", linewidth = 0.5, label = "Placebo")

# Save the Figure
plt.title("Tumor Response to Treatment")
plt.ylabel("Tumor Volume (mm3)")
plt.xlabel("Time (Days)")
plt.grid(True)
plt.legend(loc="best",fontsize ="small",fancybox=True)
#plt.show()
plt.savefig("treatment_new.png")
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

# %%
# Retrieve Drug, Timepoint,Metastatic Sites column data
metastatic_data = combined_pymaceuticals_data[["Drug", "Timepoint","Metastatic Sites"]]
# Grouped by Drug and Timepoint
avg_metastatic_vol= metastatic_data.groupby(["Drug","Timepoint"])
# Mean metastatic response
metastatic_response = avg_metastatic_vol.mean()
metastatic_response.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

# %%
# Standard Error of Tumor Volumes Grouped by Drug and Timepoint

std_err_met = avg_metastatic_vol.sem()
std_err_met.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

# %%
reformat_tumor_resp = tumor_response.reset_index().pivot("Timepoint", "Drug", "Tumor Volume (mm3)")
reformat_tumor_resp.head()
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Generate the Plot (with Error Bars)

# Save the Figure

# Show the Figure

# %%
reformat_met_resp = metastatic_response.reset_index().pivot("Timepoint", "Drug", "Metastatic Sites")
reformat_met_resp.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.320000  0.120000  0.240000   0.166667
# 10         0.565217  0.250000  0.478261   0.500000
# 15         0.764706  0.333333  0.782609   0.809524
# 20         1.000000  0.347826  0.952381   1.294118

# %%
reformat_std_err_met = std_err_met.reset_index().pivot("Timepoint", "Drug", "Metastatic Sites")
reformat_std_err_met.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.095219  0.066332  0.087178   0.077709
# 10         0.105690  0.090289  0.123672   0.109109
# 15         0.136377  0.115261  0.153439   0.111677
# 20         0.171499  0.119430  0.200905   0.166378

# %%
# Generate the Plot (with Error Bars) 
plt.errorbar(reformat_met_resp.index,reformat_met_resp["Capomulin"],yerr= reformat_std_err_met["Capomulin"],color="r",
             marker="o", markersize= 5,linestyle = "dashed", linewidth = 0.5,label= "Capomulin" )
plt.errorbar(reformat_met_resp.index,reformat_met_resp["Infubinol"],yerr= reformat_std_err_met["Infubinol"],color="b",
             marker="^", markersize= 5,linestyle = "dashed", linewidth = 0.5, label = "Infubinol")
plt.errorbar(reformat_met_resp.index,reformat_met_resp["Ketapril"],yerr= reformat_std_err_met["Ketapril"],color="g",
             marker="s", markersize= 5,linestyle = "dashed", linewidth = 0.5, label ="Ketapril" )
plt.errorbar(reformat_met_resp.index,reformat_met_resp["Placebo"],yerr= reformat_std_err_met["Placebo"],color="k",
             marker="d", markersize= 5,linestyle = "dashed", linewidth = 0.5, label ="Placebo")

# Save the Figure
plt.title("Metastatic Spread During Treatment")
plt.ylabel("Met Sites")
plt.xlabel("Treatment Duration(Days)")
plt.grid(True)
plt.legend(loc="best",fontsize ="small",fancybox=True)
#plt.show()
plt.savefig("spread_new.png")
plt.show()

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)

# Convert to DataFrame

# Preview DataFrame

# %%
#Survival Rate 
mouse_count=combined_pymaceuticals_data.groupby(["Drug","Timepoint"]).nunique()["Mouse ID"]

# Display the result in a dataframe
survival_rate =pd.DataFrame({"Mouse Count":mouse_count})
survival_rate =survival_rate.reset_index()
survival_rate.head()
# Out:
#         Drug  Timepoint  Mouse Count
# 0  Capomulin          0           25
# 1  Capomulin          5           25
# 2  Capomulin         10           25
# 3  Capomulin         15           24
# 4  Capomulin         20           23

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview the Data Frame

# %%
reformat_survival_rate = survival_rate.reset_index().pivot("Timepoint", "Drug","Mouse Count")
reformat_survival_rate.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                25        25        25         25
# 5                24        25        24         24
# 10               22        24        22         22
# 15               16        24        22         21
# 20               16        23        20         17

# %%
# Generate the Plot (Accounting for percentages)

# Save the Figure

# Show the Figure

# %%
#Survival Rate 
mouse_count=combined_pymaceuticals_data.groupby(["Drug","Timepoint"]).nunique()["Mouse ID"]
#Compute Survival Rate 
mouse_survival_rate = mouse_count.copy()

current_drug = "" 
current_drug_max_mouse_count = 0
for key, value in mouse_survival_rate.items() :
    d, t = key
    if t == 0:
        current_drug_max_mouse_count = value
    mouse_survival_rate[key] = (float(value)*100)/float(current_drug_max_mouse_count)           


# Display the result in a dataframe
survival_rate =pd.DataFrame({"Mouse Count":mouse_count, "Mouse Survival Rate": mouse_survival_rate})
survival_rate =survival_rate.reset_index()
survival_rate.head()
# Out:
#         Drug  Timepoint  Mouse Count  Mouse Survival Rate
# 0  Capomulin          0           25                  100
# 1  Capomulin          5           25                  100
# 2  Capomulin         10           25                  100
# 3  Capomulin         15           24                   96
# 4  Capomulin         20           23                   92

# %%
reformat_survival_rate = survival_rate.reset_index().pivot("Timepoint", "Drug","Mouse Count")
reformat_survival_rate = survival_rate.reset_index().pivot("Timepoint", "Drug", "Mouse Survival Rate")
reformat_survival_rate.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                100       100        100       100       100      100
# 5                100        84        100        92        92       96
# 10               100        80         84        88        84       96
# 15                96        76         84        76        84       80
# 20                92        72         80        76        80       76
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0               100       100       100        100
# 5                96       100        96         96
# 10               88        96        88         88
# 15               64        96        88         84
# 20               64        92        80         68

# %%
# Generate the Plot (with Error Bars) 
plt.errorbar(reformat_survival_rate.index,reformat_survival_rate["Capomulin"],yerr= 0,color="r",
             marker="o", markersize= 5,linestyle = "dashed", linewidth = 0.5, label = "Capomulin")
plt.errorbar(reformat_survival_rate.index,reformat_survival_rate["Infubinol"],yerr= 0,color="b",
             marker="^", markersize= 5,linestyle = "dashed", linewidth = 0.5,label = "Infubinol")
plt.errorbar(reformat_survival_rate.index,reformat_survival_rate["Ketapril"],yerr= 0,color="g",
             marker="s", markersize= 5,linestyle = "dashed", linewidth = 0.5, label= "Ketapril")
plt.errorbar(reformat_survival_rate.index,reformat_survival_rate["Placebo"],yerr= 0,color="k",
             marker="d", markersize= 5,linestyle = "dashed", linewidth = 0.5, label = "Placebo")

# Save the Figure
plt.title("Survival During Treatment")
plt.ylabel("Survival Rate(%)")
plt.xlabel("Time(days)")
plt.grid(True)
plt.legend(loc="best",fontsize ="small",fancybox=True)
#plt.show()
plt.savefig("survival_new.png")
plt.show()

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
tumor_pct_change = dict()
reformat = combined_pymaceuticals_data.groupby(["Drug"])
#reformat.head()
reformat.groups.keys()
for k in reformat.groups.keys() :
    tumor_vol_mean = reformat.get_group(k).groupby("Timepoint")["Tumor Volume (mm3)"].mean()
    tumor_vol_mean_list = tumor_vol_mean.tolist()
    first_item = tumor_vol_mean_list[0]
    last_item = tumor_vol_mean_list[len(tumor_vol_mean_list) - 1]
    tumor_vol_pct_change = ((last_item - first_item)/first_item)*100
    #print(k + "      " + str(tumor_vol_pct_change))
    tumor_pct_change[k] = tumor_vol_pct_change 
    print(k + "      " + str('{0:.6f}'.format(tumor_vol_pct_change)))
# Out:
# Capomulin      -19.475303
# Ceftamin      42.516492
# Infubinol      46.123472
# Ketapril      57.028795
# Naftisol      53.923347
# Placebo      51.297960
# Propriva      47.241175
# Ramicane      -22.320900
# Stelasyn      52.085134
# Zoniferol      46.579751

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure

# %%
#Store all Relevant Percent Changes into a Tuple
pct_changes = (tumor_pct_change["Capomulin"], 
               tumor_pct_change["Infubinol"], 
               tumor_pct_change["Ketapril"], 
               tumor_pct_change["Placebo"])
# Splice the data between passing and failing drugs
fig, ax = plt.subplots()
ind = np.arange(len(pct_changes))  
width = 1
rectsPass = ax.bar(ind[0], pct_changes[0], width, color='green')
rectsFail = ax.bar(ind[1:], pct_changes[1:], width, color='red')
# Orient widths. Add labels, tick marks, etc. 
ax.set_ylabel('% Tumor Volume Change')
ax.set_title('Tumor Change Over 45 Day Treatment')
ax.set_xticks(ind + 0.5)
ax.set_xticklabels(('Capomulin', 'Infubinol', 'Ketapril', 'Placebo'))
ax.set_autoscaley_on(False)
ax.set_ylim([-30,70])
ax.grid(True)
# Use functions to label the percentages of changes
def autolabelFail(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 3,
                '%d%%' % int(height),
                ha='center', va='bottom', color="white")
def autolabelPass(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., -8,
                '-%d%% ' % int(height),
                ha='center', va='bottom', color="white")
# Call functions to implement the function calls
autolabelPass(rectsPass)
autolabelFail(rectsFail)
# Save the Figure
fig.savefig("change_new.png")
# Show the Figure
fig.show()
